# %%
#1)Write a program in Python to produce Star triangle.
#Output:

#        *
#       ***
#      *****
#     *******
#    *********
#   ***********
#  *************
# ***************
#*****************
# Out:
# hello

# %%
#2)Explain Lambda function with an example

# %%
#3)How can you read text froma PDF file in python .You can use pyPDF2 library?

# %%
#4)How do you create dictionary using list comprehension?
#my_list=[(1,'a'),(2,'b'),(3,'c')]

# %%
#5)Explain OOPS concept in python with an example

# %%
#6)Explain logging in python with an example
import  logging

# %%
#7)Write a code to handling messaging in python using RabbitMQ consumer
import pika

# %%
#8)Explain multiprocessing with an example
import multiprocessing

# %%
#9)create a function to check if the given string is palindrome
def is_palin(s):

# %%
#10) write a function to remove duplicates from the given list
#my_lst=[3,3,5,5,6,7,7]

# %%
#11)print the animal sound in a list from the given string
#str="Well sheep says beeeee and cat says miaaaw and ciw shout mooooo"
def animal_sound(s):

# %%
#12)crate a function newxtweek(d) that returns 7 days after the date input

# %%
#13)write an example function for bubble sort?

# %%
#14)Print the indices of first n elements if list of 20 elements.

# %%
#15)what is pickling and unpickling in python?

# %%
#16)Explain the use of virtual environments in python development .When would you use virtual environments ?

# %%
#17)Create a connection with mongodb using python and perform CRUD(creat,read,update,delete) operations
#use pymongo library

# %%
#18)Create a direcctory and cerate aa file within that abd add contents to that file using python

# %%
#19)Write a function to return second largest element from the list

# %%
#20)Write a python function to check if a given list is sorted in non-decreasing order
